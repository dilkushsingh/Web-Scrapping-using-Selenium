# %% [markdown]
# # Data Assessing

# %%
import numpy as np
import pandas as pd

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
smartphones = pd.read_csv('smartphones.csv')

# %%
smartphones
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 0                      vivo V40  34,999            NaN                   NaN
# 1                     OPPO K12x  12,999            NaN                   NaN
# 2                  vivo V40 Pro  49,999            8.2                   NaN
# 3       Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 4         Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2923                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2924              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2925         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2926  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2927       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#                                    processor             rear_cameras  \
# 0               Snapdragon 7 Gen 3 Octa core     50+50 MP Rear Camera
# 1          MediaTek Dimensity 6300 Octa core      32+2 MP Rear Camera
# 2     MediaTek Dimensity 9200 Plus Octa core  50+50+50 MP Rear Camera
# 3              Snapdragon 7s Gen 2 Octa core     50+13 MP Rear Camera
# 4              Samsung Exynos 1380 Octa core    50+8+2 MP Rear Camera
# ...                                      ...                      ...
# 2923                                MediaTek        13 MP Rear Camera
# 2924               HiSilicon Kirin Octa core      12+2 MP Rear Camera
# 2925                      MediaTek Quad core         8 MP Rear Camera
# 2926                      MediaTek Quad core         8 MP Rear Camera
# 2927                      MediaTek Quad core         5 MP Rear Camera
#
#            front_cameras                                     display  \
# 0     50 MP Front Camera       6.78″ (17.22 cm) 120Hz AMOLED Display
# 1      8 MP Front Camera          6.67″ (16.94 cm) 120Hz LCD Display
# 2     50 MP Front Camera       6.78″ (17.22 cm) 120Hz AMOLED Display
# 3     32 MP Front Camera       6.67″ (16.94 cm) 144Hz P-OLED Display
# 4     13 MP Front Camera  6.6″ (16.76 cm) 120Hz Super AMOLED Display
# ...                  ...                                         ...
# 2923   5 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2924   8 MP Front Camera             5.5″ (13.97 cm) IPS LCD Display
# 2925   2 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2926   5 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2927   5 MP Front Camera             5.5″ (13.97 cm) IPS LCD Display
#
#             ram_internal_memory                       battery  \
# 0     8 GB RAM | 128 GB Storage  5500 mAh | 80W Fast Charging
# 1     6 GB RAM | 128 GB Storage  5100 mAh | 45W Fast Charging
# 2     8 GB RAM | 256 GB Storage  5500 mAh | 80W Fast Charging
# 3     8 GB RAM | 128 GB Storage  5000 mAh | 68W Fast Charging
# 4     6 GB RAM | 128 GB Storage  6000 mAh | 25W Fast Charging
# ...                         ...                           ...
# 2923   2 GB RAM | 16 GB Storage                      2500 mAh
# 2924   3 GB RAM | 32 GB Storage                      3340 mAh
# 2925   2 GB RAM | 16 GB Storage                      3000 mAh
# 2926    1 GB RAM | 8 GB Storage                      2300 mAh
# 2927   2 GB RAM | 16 GB Storage                      2800 mAh
#
#        operating_system            additional_features  \
# 0        Android v14 OS        5G | Fingerprint Sensor
# 1        Android v14 OS        5G | Fingerprint Sensor
# 2        Android v14 OS        5G | Fingerprint Sensor
# 3        Android v14 OS  5G | NFC | Fingerprint Sensor
# 4        Android v14 OS  5G | NFC | Fingerprint Sensor
# ...                 ...                            ...
# 2923    Android v6.0 OS                            NaN
# 2924  Android v6.0.1 OS             Fingerprint Sensor
# 2925    Android v6.0 OS                            NaN
# 2926    Android v6.0 OS                            NaN
# 2927    Android v6.0 OS             Fingerprint Sensor
#
#                                                  review  \
# 0                                                   NaN
# 1                                                   NaN
# 2     The Vivo V40 Pro shines with its cameras, perf...
# 3     Moto Edge 50 Fusion has a premium design and s...
# 4                                                   NaN
# ...                                                 ...
# 2923                                                NaN
# 2924                                                NaN
# 2925                                                NaN
# 2926                                                NaN
# 2927                                                NaN
#
#                                             review_link
# 0                                                   NaN
# 1                                                   NaN
# 2     https://www.mysmartprice.com/gear/mobiles/mobi...
# 3     https://www.mysmartprice.com/gear/mobiles/mobi...
# 4                                                   NaN
# ...                                                 ...
# 2923                                                NaN
# 2924                                                NaN
# 2925                                                NaN
# 2926                                                NaN
# 2927                                                NaN
#
# [2928 rows x 14 columns]

# %% [markdown]
# ### Quality Issues
#
# 1. model_name - some mobiles names contains variant info. `consistency`
# 2. model_name - some motorola phones only has model name not brand name. `validity`
# 3. price - has ',' between numbers. `validity`
# 4. expert_rating - missing values. `completeness`
# 5. user_rating - missing values. `completeness`
# 6. processor - missing values. `completeness`
# 7. processor - some values has only core or processor brand info. `accuracy`
# 8. rear_camera - multiple cameras all are in same cell, represented using +. `validity`
# 9. front_camera - missing values. `completeness`
# 10. display - some values only contains type of display(LCD) `accuracy`
# 11. ram_internal_memory - missing values. `completeness`
# 12. ram_internal_memory - some values has only storage info. `accuracy`
# 13. battery - some values only has battery info not charging. `accuracy`
# 14. operating_system - missing values. `completeness`
# 15. additional_features - missing values. `completeness`
# 16. review and review_link - missing values. `completeness`
# 17. review - contains incomplete reviews. `validity`
#
# ### Tidiness Issues
# 1. user_rating - can be split into 2 cols user_rating and num_ratings.
# 2. processor - can be split into processor name, processor brand, cores.
# 3. rear_cameras and front_cameras - need to do something.
# 4. display - can be split into size, refresh rate and type of display.
# 5. ram_internal_memory - can be split into RAM and internal memory.
# 6. battery - can be split into battery capacity and charging.
# 7. additional_features - can be split into has_5g, has_nfc, has_fingerprint_sensor
# 8. review and review_link shouldn't be exist, they are irrelevant for further processing.
# 9. model_name - another col 'brand_name' can be created.
# 10. operating_system - split into two cols os_type, os_version

# %% [markdown]
# Creating a copy of DataFrame so that it will be easy to revert back to original DF.

# %%
df = smartphones.copy()

# %%
df.shape
# Out:
# (2928, 14)

# %% [markdown]
# Checking Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_name           2928 non-null   object
#  1   price                2928 non-null   object
#  2   expert_rating        1827 non-null   float64
#  3   user_rating          2832 non-null   object
#  4   processor            2888 non-null   object
#  5   rear_cameras         2928 non-null   object
#  6   front_cameras        2895 non-null   object
#  7   display              2928 non-null   object
#  8   ram_internal_memory  2926 non-null   object
#  9   battery              2928 non-null   object
#  10  operating_system     2919 non-null   object
#  11  additional_features  2312 non-null   object
#  12  review               1419 non-null   object
#  13  review_link          1419 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 320.4+ KB

# %%
df.describe()
# Out:
#        expert_rating
# count    1827.000000
# mean        7.806951
# std         0.600576
# min         3.500000
# 25%         7.500000
# 50%         7.800000
# 75%         8.100000
# max         9.500000

# %% [markdown]
# Checking duplicate values and removing them

# %%
df.duplicated().sum()
# Out:
# 672

# %%
df[df.duplicated()]
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 48                     vivo V40  34,999            NaN                   NaN
# 49                    OPPO K12x  12,999            NaN                   NaN
# 50                 vivo V40 Pro  49,999            8.2                   NaN
# 51      Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 52        Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2923                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2924              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2925         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2926  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2927       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#                                    processor             rear_cameras  \
# 48              Snapdragon 7 Gen 3 Octa core     50+50 MP Rear Camera
# 49         MediaTek Dimensity 6300 Octa core      32+2 MP Rear Camera
# 50    MediaTek Dimensity 9200 Plus Octa core  50+50+50 MP Rear Camera
# 51             Snapdragon 7s Gen 2 Octa core     50+13 MP Rear Camera
# 52             Samsung Exynos 1380 Octa core    50+8+2 MP Rear Camera
# ...                                      ...                      ...
# 2923                                MediaTek        13 MP Rear Camera
# 2924               HiSilicon Kirin Octa core      12+2 MP Rear Camera
# 2925                      MediaTek Quad core         8 MP Rear Camera
# 2926                      MediaTek Quad core         8 MP Rear Camera
# 2927                      MediaTek Quad core         5 MP Rear Camera
#
#            front_cameras                                     display  \
# 48    50 MP Front Camera       6.78″ (17.22 cm) 120Hz AMOLED Display
# 49     8 MP Front Camera          6.67″ (16.94 cm) 120Hz LCD Display
# 50    50 MP Front Camera       6.78″ (17.22 cm) 120Hz AMOLED Display
# 51    32 MP Front Camera       6.67″ (16.94 cm) 144Hz P-OLED Display
# 52    13 MP Front Camera  6.6″ (16.76 cm) 120Hz Super AMOLED Display
# ...                  ...                                         ...
# 2923   5 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2924   8 MP Front Camera             5.5″ (13.97 cm) IPS LCD Display
# 2925   2 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2926   5 MP Front Camera              5.0″ (12.7 cm) IPS LCD Display
# 2927   5 MP Front Camera             5.5″ (13.97 cm) IPS LCD Display
#
#             ram_internal_memory                       battery  \
# 48    8 GB RAM | 128 GB Storage  5500 mAh | 80W Fast Charging
# 49    6 GB RAM | 128 GB Storage  5100 mAh | 45W Fast Charging
# 50    8 GB RAM | 256 GB Storage  5500 mAh | 80W Fast Charging
# 51    8 GB RAM | 128 GB Storage  5000 mAh | 68W Fast Charging
# 52    6 GB RAM | 128 GB Storage  6000 mAh | 25W Fast Charging
# ...                         ...                           ...
# 2923   2 GB RAM | 16 GB Storage                      2500 mAh
# 2924   3 GB RAM | 32 GB Storage                      3340 mAh
# 2925   2 GB RAM | 16 GB Storage                      3000 mAh
# 2926    1 GB RAM | 8 GB Storage                      2300 mAh
# 2927   2 GB RAM | 16 GB Storage                      2800 mAh
#
#        operating_system            additional_features  \
# 48       Android v14 OS        5G | Fingerprint Sensor
# 49       Android v14 OS        5G | Fingerprint Sensor
# 50       Android v14 OS        5G | Fingerprint Sensor
# 51       Android v14 OS  5G | NFC | Fingerprint Sensor
# 52       Android v14 OS  5G | NFC | Fingerprint Sensor
# ...                 ...                            ...
# 2923    Android v6.0 OS                            NaN
# 2924  Android v6.0.1 OS             Fingerprint Sensor
# 2925    Android v6.0 OS                            NaN
# 2926    Android v6.0 OS                            NaN
# 2927    Android v6.0 OS             Fingerprint Sensor
#
#                                                  review  \
# 48                                                  NaN
# 49                                                  NaN
# 50    The Vivo V40 Pro shines with its cameras, perf...
# 51    Moto Edge 50 Fusion has a premium design and s...
# 52                                                  NaN
# ...                                                 ...
# 2923                                                NaN
# 2924                                                NaN
# 2925                                                NaN
# 2926                                                NaN
# 2927                                                NaN
#
#                                             review_link
# 48                                                  NaN
# 49                                                  NaN
# 50    https://www.mysmartprice.com/gear/mobiles/mobi...
# 51    https://www.mysmartprice.com/gear/mobiles/mobi...
# 52                                                  NaN
# ...                                                 ...
# 2923                                                NaN
# 2924                                                NaN
# 2925                                                NaN
# 2926                                                NaN
# 2927                                                NaN
#
# [672 rows x 14 columns]

# %%
# code
df.drop_duplicates(inplace=True)

# %%
# test
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2256, 14)

# %% [markdown]
# ### According to the order of severity, we follow the Data cleaning Order.
#
#
# 1. Quality -> Completeness
# 2. Tidiness
# 3. Quality -> Validity
# 4. Quality -> Accuracy
# 5. Quality -> Consistency
#
# #### Steps involved in Data cleaning
# - Define
# - Code
# - Test

# %% [markdown]
# ## Fetching rows having more missing values
# since they seems to be outliers, so dropping them or filling them will help in maintaining quality of data

# %%
df.isna().sum()
# Out:
# model_name                0
# price                     0
# expert_rating           858
# user_rating              71
# processor                37
# rear_cameras              0
# front_cameras            32
# display                   0
# ram_internal_memory       2
# battery                   0
# operating_system          9
# additional_features     502
# review                 1186
# review_link            1186
# dtype: int64

# %%
df[df[['user_rating', 'processor', 'front_cameras', 'ram_internal_memory', 'operating_system']].isnull().all(axis=1)]
# Out:
#                  model_name   price  expert_rating user_rating processor  \
# 2417  Blackberry Curve 8900  18,990            NaN         NaN       NaN
#
#             rear_cameras front_cameras      display ram_internal_memory  \
# 2417  3.2 MP Rear Camera           NaN  LCD Display                 NaN
#
#                battery operating_system additional_features review review_link
# 2417  1400 mAh Battery              NaN                 NaN    NaN         NaN

# %%
df.drop(2417, inplace=True)

# %%
df[df[['processor', 'front_cameras', 'operating_system']].isnull().all(axis=1)]
# Out:
#                     model_name   price  expert_rating           user_rating  \
# 1598            Nokia Asha 311   5,049            NaN    4.4 ★\n902 Ratings
# 2036            Nokia Asha 210   5,659            NaN  3.8 ★\n1,727 Ratings
# 2416  Blackberry Curve 3G 9300  10,200            NaN    2.5 ★\n642 Ratings
# 2418          Nokia 6700 Slide  11,049            NaN                   NaN
# 2419                  Nokia C3   9,999            NaN    3.1 ★\n136 Ratings
# 2442                 Nokia 301   5,675            NaN  1.0 ★\n4,807 Ratings
# 2456          Karbonn A18 Plus   5,314            NaN    3.3 ★\n575 Ratings
#
#      processor        rear_cameras front_cameras  \
# 1598       NaN  3.2 MP Rear Camera           NaN
# 2036       NaN    2 MP Rear Camera           NaN
# 2416       NaN    2 MP Rear Camera           NaN
# 2418       NaN    5 MP Rear Camera           NaN
# 2419       NaN    2 MP Rear Camera           NaN
# 2442       NaN  3.2 MP Rear Camera           NaN
# 2456       NaN    5 MP Rear Camera           NaN
#
#                              display          ram_internal_memory  \
# 1598        3″ (7.62 cm) TFT Display  128 MB RAM | 256 MB Storage
# 2036       2.4″ (6.1 cm) TFT Display    32 MB RAM | 64 MB Storage
# 2416       2.4″ (6.1 cm) LCD Display               256 MB Storage
# 2418      2.2″ (5.59 cm) LCD Display                60 MB Storage
# 2419       2.4″ (6.1 cm) LCD Display                55 MB Storage
# 2442       2.4″ (6.1 cm) TFT Display   64 MB RAM | 256 MB Storage
# 2456  5.0″ (12.7 cm) IPS LCD Display    512 MB RAM | 4 GB Storage
#
#                battery operating_system additional_features review review_link
# 1598  1110 mAh Battery              NaN                 NaN    NaN         NaN
# 2036  1200 mAh Battery              NaN                 NaN    NaN         NaN
# 2416  1150 mAh Battery              NaN                 NaN    NaN         NaN
# 2418   860 mAh Battery              NaN                 NaN    NaN         NaN
# 2419  1320 mAh Battery              NaN                 NaN    NaN         NaN
# 2442  1200 mAh Battery              NaN                 NaN    NaN         NaN
# 2456  2000 mAh Battery              NaN                 NaN    NaN         NaN

# %%
df.drop([1598, 2036, 2416, 2418, 2419, 2442, 2456], inplace=True)

# %%
df[df[['processor', 'front_cameras', 'operating_system']].isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [model_name, price, expert_rating, user_rating, processor, rear_cameras, front_cameras, display, ram_internal_memory, battery, operating_system, additional_features, review, review_link]
# Index: []

# %%
df.isna().sum()
# Out:
# model_name                0
# price                     0
# expert_rating           850
# user_rating              69
# processor                29
# rear_cameras              0
# front_cameras            24
# display                   0
# ram_internal_memory       1
# battery                   0
# operating_system          1
# additional_features     494
# review                 1178
# review_link            1178
# dtype: int64

# %%
df[df[['operating_system', 'ram_internal_memory']].isnull().any(axis=1)]
# Out:
#                 model_name  price  expert_rating        user_rating processor  \
# 2434         Lava Iris 502  9,999            NaN  2.0 ★\n96 Ratings       NaN
# 2447  Micromax Bling 3 A86  6,000            NaN  3.5 ★\n32 Ratings       NaN
#
#           rear_cameras        front_cameras                    display  \
# 2434  5 MP Rear Camera  0.3 MP Front Camera   5″ (12.7 cm) LCD Display
# 2447  5 MP Rear Camera  0.3 MP Front Camera  4″ (10.16 cm) TFT Display
#
#             ram_internal_memory           battery operating_system  \
# 2434  512 MB RAM | 4 GB Storage  2000 mAh Battery              NaN
# 2447                        NaN  1600 mAh Battery  Android v4.1 OS
#
#      additional_features review review_link
# 2434                 NaN    NaN         NaN
# 2447                 NaN    NaN         NaN

# %%
df.loc[2434, 'operating_system'] =  "Android v4.1 OS"
df.loc[2434, 'processor'] = 'Dual Core'

# %%
df.loc[2447, 'processor'] = 'Dual Core'
df.loc[2447, 'ram_internal_memory'] = '512 MB RAM'

# %% [markdown]
# ## Let's Start handling issues One by one

# %% [markdown]
# expert_rating - missing values. `completeness`
#
# According to me, the better way to fill missing values in expert_rating column is by using knn imputer, but knn imputer requires number columns and since we are just starting, we will fill them later.

# %% [markdown]
# user_rating - missing values. `completeness`
#
# we can't predict that how many users will rate a specific mobile, so filling with 0 is a option but on further processing it will create chaos. so as like expert ratings, we will use knn imputer, but for that firstly we have to change it to numeric columns

# %%
df['user_rating'].replace('0', np.nan)
# Out:
# 0                          0
# 1                          0
# 2                          0
# 3       4.5 ★\n16.9K Ratings
# 4         4.3 ★\n383 Ratings
#                 ...
# 2875       3.7 ★\n80 Ratings
# 2876    4.5 ★\n35.9K Ratings
# 2877      3.0 ★\n772 Ratings
# 2878      3.8 ★\n195 Ratings
# 2879    3.9 ★\n1,253 Ratings
# Name: user_rating, Length: 2248, dtype: object

# %% [markdown]
# processor - missing values. `completeness`
#
# Filling missing values with 'unknown' should be preferred.

# %%
df['processor'].isna().sum()
# Out:
# 28

# %%
df.loc[[1597, 2037, 2053, 2420, 2421, 2422, 2423, 2424, 2425, 2426], 'processor'] = 'Single Core'
df.loc[[2280, 2406, 2429, 2434, 2444, 2457, 2459, 2463, 2468, 2472, 2489, 2495], 'processor'] = 'Dual Core'
df.loc[[2523, 2538, 2625, 2627, 2666, 2717], 'processor'] = 'Quad Core'

# %%
# test
df['processor'].isna().sum()
# Out:
# 0

# %% [markdown]
# front_camera - missing values. `completeness`
#
# Filling values by using chatgpt.

# %%
df['front_cameras'].isna().sum()
# Out:
# 24

# %%
df[df['front_cameras'].isna()]
# Out:
#                            model_name   price  expert_rating  \
# 1414                 Sony Xperia tipo   6,299            NaN
# 1549             Blackberry Bold 9780  27,990            NaN
# 1597         Blackberry Pearl 3G 9105  20,990            NaN
# 1624                 Intex Aqua Twist   5,590            NaN
# 2037            Blackberry Curve 8520  10,900            NaN
# 2038         Sony Ericsson Xperia X10  35,795            NaN
# 2052                  Nokia Lumia 800  13,299            NaN
# 2053            Blackberry Curve 9320   9,799            NaN
# 2057                  Blackberry 9720  15,250            7.1
# 2128                    Nokia 8110 4G   5,999            7.0
# 2374                     Oukitel WP21  33,102            NaN
# 2407       Sony Ericsson Xperia Arc S  28,345            NaN
# 2422                         Nokia E5   8,231            NaN
# 2423                      Nokia C5-03   7,920            NaN
# 2425                   Nokia 500 Fate   5,209            NaN
# 2426                      Nokia C5-05   9,315            NaN
# 2428            Sony Xperia tipo dual   6,050            NaN
# 2430                  Nokia Lumia 510   7,589            NaN
# 2431                    Sony Xperia E   5,090            NaN
# 2433                  Nokia Lumia 520   5,500            NaN
# 2436            LG Optimus L3 II E425   5,149            NaN
# 2445           Spice Coolpad 2 Mi-496  11,990            NaN
# 2452  Samsung Galaxy Trend Duos S7392   5,490            NaN
# 2457                Karbonn Smart A5i   5,740            NaN
#
#                user_rating                     processor  \
# 1414  4.8 ★\n2,293 Ratings                    Snapdragon
# 1549     3.6 ★\n59 Ratings                       Marvell
# 1597     3.1 ★\n94 Ratings                   Single Core
# 1624     3.7 ★\n86 Ratings            MediaTek Quad core
# 2037    4.0 ★\n498 Ratings                   Single Core
# 2038     3.9 ★\n32 Ratings                 Snapdragon S1
# 2052    4.4 ★\n729 Ratings                 Snapdragon S2
# 2053  2.5 ★\n2,641 Ratings                   Single Core
# 2057    4.0 ★\n385 Ratings                       Marvell
# 2128  1.0 ★\n3,286 Ratings      Snapdragon 205 Dual core
# 2374     3.7 ★\n50 Ratings  MediaTek Helio G99 Octa core
# 2407    4.3 ★\n214 Ratings                 Snapdragon S2
# 2422    5.0 ★\n366 Ratings                   Single Core
# 2423    1.0 ★\n137 Ratings                   Single Core
# 2425    4.0 ★\n300 Ratings                   Single Core
# 2426    3.8 ★\n181 Ratings                   Single Core
# 2428    3.2 ★\n851 Ratings                 Snapdragon S1
# 2430    3.9 ★\n802 Ratings                 Snapdragon S1
# 2431  3.4 ★\n2,478 Ratings                    Snapdragon
# 2433  4.1 ★\n27.2K Ratings            Snapdragon S4 Plus
# 2436     4.1 ★\n30 Ratings                 Snapdragon S1
# 2445     1.0 ★\n64 Ratings                      MediaTek
# 2452  3.7 ★\n2,056 Ratings                   Single core
# 2457    3.4 ★\n187 Ratings                     Dual Core
#
#                 rear_cameras front_cameras  \
# 1414      3.2 MP Rear Camera           NaN
# 1549        5 MP Rear Camera           NaN
# 1597      3.2 MP Rear Camera           NaN
# 1624        5 MP Rear Camera           NaN
# 2037        2 MP Rear Camera           NaN
# 2038      8.1 MP Rear Camera           NaN
# 2052        8 MP Rear Camera           NaN
# 2053      3.2 MP Rear Camera           NaN
# 2057        5 MP Rear Camera           NaN
# 2128        2 MP Rear Camera           NaN
# 2374  64+2+20 MP Rear Camera           NaN
# 2407      8.1 MP Rear Camera           NaN
# 2422        5 MP Rear Camera           NaN
# 2423        5 MP Rear Camera           NaN
# 2425        5 MP Rear Camera           NaN
# 2426        2 MP Rear Camera           NaN
# 2428      3.2 MP Rear Camera           NaN
# 2430        5 MP Rear Camera           NaN
# 2431      3.2 MP Rear Camera           NaN
# 2433        5 MP Rear Camera           NaN
# 2436        3 MP Rear Camera           NaN
# 2445        5 MP Rear Camera           NaN
# 2452        3 MP Rear Camera           NaN
# 2457        3 MP Rear Camera           NaN
#
#                                      display          ram_internal_memory  \
# 1414              3.2″ (8.13 cm) TFT Display  512 MB RAM | 2.9 GB Storage
# 1549               2.4″ (6.1 cm) TFT Display  512 MB RAM | 256 MB Storage
# 1597             2.25″ (5.72 cm) TFT Display               256 MB Storage
# 1624          5.0″ (12.7 cm) IPS LCD Display      1 GB RAM | 8 GB Storage
# 2037               2.4″ (6.1 cm) TFT Display  128 MB RAM | 256 MB Storage
# 2038               4″ (10.16 cm) LCD Display    384 MB RAM | 1 GB Storage
# 2052            3.7″ (9.4 cm) AMOLED Display   512 MB RAM | 16 GB Storage
# 2053              2.44″ (6.2 cm) TFT Display  512 MB RAM | 512 MB Storage
# 2057          2.8″ (7.11 cm) IPS LCD Display  512 MB RAM | 512 MB Storage
# 2128             2.45″ (6.22 cm) TFT Display    512 MB RAM | 4 GB Storage
# 2374  6.78″ (17.22 cm) 120Hz IPS LCD Display   12 GB RAM | 256 GB Storage
# 2407             4.2″ (10.67 cm) LCD Display    512 MB RAM | 1 GB Storage
# 2422               2.4″ (6.1 cm) LCD Display               256 MB Storage
# 2423              3.2″ (8.13 cm) LCD Display   128 MB RAM | 40 MB Storage
# 2425              3.2″ (8.13 cm) TFT Display  256 MB RAM | 512 MB Storage
# 2426              3.2″ (8.13 cm) LCD Display  128 MB RAM | 256 MB Storage
# 2428              3.2″ (8.13 cm) TFT Display  512 MB RAM | 2.9 GB Storage
# 2430               4″ (10.16 cm) LCD Display    256 MB RAM | 4 GB Storage
# 2431              3.5″ (8.89 cm) LCD Display    512 MB RAM | 4 GB Storage
# 2433           4″ (10.16 cm) IPS LCD Display    512 MB RAM | 8 GB Storage
# 2436          3.2″ (8.13 cm) IPS LCD Display    512 MB RAM | 4 GB Storage
# 2445             4.5″ (11.43 cm) LCD Display      1 GB RAM | 4 GB Storage
# 2452               4″ (10.16 cm) TFT Display    512 MB RAM | 4 GB Storage
# 2457              3.5″ (8.89 cm) TFT Display  512 MB RAM | 512 MB Storage
#
#                            battery       operating_system  \
# 1414              1500 mAh Battery      Android v4.0.4 OS
# 1549              1500 mAh Battery       Blackberry v6 OS
# 1597              1150 mAh Battery   Blackberry v5.0.x OS
# 1624                      2200 mAh        Android v5.1 OS
# 2037              1150 mAh Battery   Blackberry v5.0.x OS
# 2038              1500 mAh Battery        Android v1.6 OS
# 2052              1450 mAh Battery  Windows Phone v7.5 OS
# 2053              1450 mAh Battery     Blackberry v7.1 OS
# 2057              1450 mAh Battery     Blackberry v7.1 OS
# 2128                      1500 mAh              KAI OS OS
# 2374  9800 mAh | 66W Fast Charging         Android v12 OS
# 2407              1500 mAh Battery      Android v2.3.4 OS
# 2422              1200 mAh Battery             Symbian OS
# 2423              1000 mAh Battery             Symbian OS
# 2425              1110 mAh Battery             Symbian OS
# 2426              1000 mAh Battery             Symbian OS
# 2428              1500 mAh Battery          Android v4 OS
# 2430              1300 mAh Battery  Windows Phone v7.8 OS
# 2431              1530 mAh Battery        Android v4.1 OS
# 2433              1430 mAh Battery    Windows Phone v8 OS
# 2436              1540 mAh Battery        Android v4.1 OS
# 2445              1700 mAh Battery        Android v4.1 OS
# 2452              1500 mAh Battery      Android v4.1.2 OS
# 2457              1420 mAh Battery        Android v2.3 OS
#
#            additional_features review review_link
# 1414                       NaN    NaN         NaN
# 1549                       NaN    NaN         NaN
# 1597                       NaN    NaN         NaN
# 1624                       NaN    NaN         NaN
# 2037                       NaN    NaN         NaN
# 2038                       NaN    NaN         NaN
# 2052                       NaN    NaN         NaN
# 2053                       NaN    NaN         NaN
# 2057                       NaN    NaN         NaN
# 2128                       NaN    NaN         NaN
# 2374  NFC | Fingerprint Sensor    NaN         NaN
# 2407                       NaN    NaN         NaN
# 2422                       NaN    NaN         NaN
# 2423                       NaN    NaN         NaN
# 2425                       NaN    NaN         NaN
# 2426                       NaN    NaN         NaN
# 2428                       NaN    NaN         NaN
# 2430                       NaN    NaN         NaN
# 2431                       NaN    NaN         NaN
# 2433                       NaN    NaN         NaN
# 2436                       NaN    NaN         NaN
# 2445                       NaN    NaN         NaN
# 2452                       NaN    NaN         NaN
# 2457                       NaN    NaN         NaN

# %%
df.loc[[1414, 1549, 1597, 1624, 2037, 2053, 2057, 2128, 2422, 2423, 2425, 2426, 2428, 2436, 2445, 2457], 'front_cameras'] = '0 MP Front Camera'
df.loc[[2038, 2407], 'front_cameras'] = '1.3 MP Front Camera'
df.loc[[2052, 2430, 2431, 2433, 2452], 'front_cameras'] = '0.3 MP Front Camera'
df.loc[[2374], 'front_cameras'] = '20 MP Front Camera'

# %%
df.isna().sum()
# Out:
# model_name                0
# price                     0
# expert_rating           850
# user_rating               0
# processor                 0
# rear_cameras              0
# front_cameras             0
# display                   0
# ram_internal_memory       0
# battery                   0
# operating_system          0
# additional_features     494
# review                 1178
# review_link            1178
# dtype: int64

# %% [markdown]
# additional_features - missing values. `completeness`
#
# this column contains that phone has 5g, nfc, or fingerprint sensor. null value means phone doesn't have any of the three features, so we will fill it with "No add features"

# %%
df['additional_features'].isna().sum()
# Out:
# 494

# %%
df.fillna({'additional_features': 'No add features'}, inplace=True)

# %%
df['additional_features'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# model_name                0
# price                     0
# expert_rating           850
# user_rating               0
# processor                 0
# rear_cameras              0
# front_cameras             0
# display                   0
# ram_internal_memory       0
# battery                   0
# operating_system          0
# additional_features       0
# review                 1178
# review_link            1178
# dtype: int64

# %% [markdown]
# ### Handling Tidiness Issues.

# %% [markdown]
# Dropping irrelevant columns

# %%
df.drop(columns=['review', 'review_link'], inplace=True)

# %% [markdown]
# user_rating - can be split into 2 cols user_rating and num_ratings.
#
# missing values can be handled after filling up the missing values, also dtype will be corrected

# %%
df['user_rating'].value_counts()
# Out:
# user_rating
# 0                       69
# 4.5 ★\n1.3L Ratings      9
# 4.2 ★\n1.1L Ratings      8
# 4.2 ★\n1L Ratings        6
# 4.3 ★\n1.4L Ratings      6
#                         ..
# 4.4 ★\n54K Ratings       1
# 4.2 ★\n14.9K Ratings     1
# 4.1 ★\n1,394 Ratings     1
# 4.3 ★\n2,041 Ratings     1
# 3.9 ★\n1,253 Ratings     1
# Name: count, Length: 1796, dtype: int64

# %%
user_ratings = df['user_rating'].str.strip().str.split('\n').str.get(0).str.split(' ').str.get(0)

# %%
num_ratings = df['user_rating'].str.strip().str.split('\n').str.get(1).str.split(' ').str.get(0)

# %%
df.insert(4, 'avg_user_rating', user_ratings)
df.insert(5, 'num_ratings', num_ratings)

# %%
df
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 0                      vivo V40  34,999            NaN                     0
# 1                     OPPO K12x  12,999            NaN                     0
# 2                  vivo V40 Pro  49,999            8.2                     0
# 3       Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 4         Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2875                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2876              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2877         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2878  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2879       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#      avg_user_rating num_ratings                               processor  \
# 0                NaN         NaN            Snapdragon 7 Gen 3 Octa core
# 1                NaN         NaN       MediaTek Dimensity 6300 Octa core
# 2                NaN         NaN  MediaTek Dimensity 9200 Plus Octa core
# 3                4.5       16.9K           Snapdragon 7s Gen 2 Octa core
# 4                4.3         383           Samsung Exynos 1380 Octa core
# ...              ...         ...                                     ...
# 2875             3.7          80                                MediaTek
# 2876             4.5       35.9K               HiSilicon Kirin Octa core
# 2877             3.0         772                      MediaTek Quad core
# 2878             3.8         195                      MediaTek Quad core
# 2879             3.9       1,253                      MediaTek Quad core
#
#                  rear_cameras       front_cameras  \
# 0        50+50 MP Rear Camera  50 MP Front Camera
# 1         32+2 MP Rear Camera   8 MP Front Camera
# 2     50+50+50 MP Rear Camera  50 MP Front Camera
# 3        50+13 MP Rear Camera  32 MP Front Camera
# 4       50+8+2 MP Rear Camera  13 MP Front Camera
# ...                       ...                 ...
# 2875        13 MP Rear Camera   5 MP Front Camera
# 2876      12+2 MP Rear Camera   8 MP Front Camera
# 2877         8 MP Rear Camera   2 MP Front Camera
# 2878         8 MP Rear Camera   5 MP Front Camera
# 2879         5 MP Rear Camera   5 MP Front Camera
#
#                                          display        ram_internal_memory  \
# 0          6.78″ (17.22 cm) 120Hz AMOLED Display  8 GB RAM | 128 GB Storage
# 1             6.67″ (16.94 cm) 120Hz LCD Display  6 GB RAM | 128 GB Storage
# 2          6.78″ (17.22 cm) 120Hz AMOLED Display  8 GB RAM | 256 GB Storage
# 3          6.67″ (16.94 cm) 144Hz P-OLED Display  8 GB RAM | 128 GB Storage
# 4     6.6″ (16.76 cm) 120Hz Super AMOLED Display  6 GB RAM | 128 GB Storage
# ...                                          ...                        ...
# 2875              5.0″ (12.7 cm) IPS LCD Display   2 GB RAM | 16 GB Storage
# 2876             5.5″ (13.97 cm) IPS LCD Display   3 GB RAM | 32 GB Storage
# 2877              5.0″ (12.7 cm) IPS LCD Display   2 GB RAM | 16 GB Storage
# 2878              5.0″ (12.7 cm) IPS LCD Display    1 GB RAM | 8 GB Storage
# 2879             5.5″ (13.97 cm) IPS LCD Display   2 GB RAM | 16 GB Storage
#
#                            battery   operating_system  \
# 0     5500 mAh | 80W Fast Charging     Android v14 OS
# 1     5100 mAh | 45W Fast Charging     Android v14 OS
# 2     5500 mAh | 80W Fast Charging     Android v14 OS
# 3     5000 mAh | 68W Fast Charging     Android v14 OS
# 4     6000 mAh | 25W Fast Charging     Android v14 OS
# ...                            ...                ...
# 2875                      2500 mAh    Android v6.0 OS
# 2876                      3340 mAh  Android v6.0.1 OS
# 2877                      3000 mAh    Android v6.0 OS
# 2878                      2300 mAh    Android v6.0 OS
# 2879                      2800 mAh    Android v6.0 OS
#
#                 additional_features
# 0           5G | Fingerprint Sensor
# 1           5G | Fingerprint Sensor
# 2           5G | Fingerprint Sensor
# 3     5G | NFC | Fingerprint Sensor
# 4     5G | NFC | Fingerprint Sensor
# ...                             ...
# 2875                No add features
# 2876             Fingerprint Sensor
# 2877                No add features
# 2878                No add features
# 2879             Fingerprint Sensor
#
# [2248 rows x 14 columns]

# %%
def unit_converter(num):
    lastDigit = str(num)[-1]
    if lastDigit == 'K':
        return float(num[:-1])*1000
    elif lastDigit == 'L':
        return float(num[:-1])*100000
    else:
        return float(str(num).replace(',', ''))

# %%
df['num_ratings'] = df['num_ratings'].apply(unit_converter)

# %% [markdown]
# processor - can be split into processor name, processor brand, cores.

# %%
df['processor'].value_counts()
# Out:
# processor
# Unisoc Octa core                92
# MediaTek                        83
# MediaTek Quad core              79
# MediaTek Tru-Octa Core          70
# MediaTek Helio G85 Octa core    51
#                                 ..
# Snapdragon 410 Octa core         1
# Apple A4                         1
# Snapdragon S2 Single core        1
# Snapdragon 400 Dual core         1
# Snapdragon 415 Tru-Octa Core     1
# Name: count, Length: 233, dtype: int64

# %%
processor_brand = df['processor'].str.split(' ').str.get(0)

# %%
df.columns
# Out:
# Index(['model_name', 'price', 'expert_rating', 'user_rating',
#        'avg_user_rating', 'num_ratings', 'processor', 'rear_cameras',
#        'front_cameras', 'display', 'ram_internal_memory', 'battery',
#        'operating_system', 'additional_features'],
#       dtype='object')

# %%
df.insert(7, 'processor_brand', processor_brand)

# %%
top_brands = df['processor_brand'].value_counts().head().index.tolist()

df['processor_brand'] = df['processor_brand'].apply(lambda x: x if x in top_brands else 'Other')

# %%
df['processor'].value_counts()
# Out:
# processor
# Unisoc Octa core                92
# MediaTek                        83
# MediaTek Quad core              79
# MediaTek Tru-Octa Core          70
# MediaTek Helio G85 Octa core    51
#                                 ..
# Snapdragon 410 Octa core         1
# Apple A4                         1
# Snapdragon S2 Single core        1
# Snapdragon 400 Dual core         1
# Snapdragon 415 Tru-Octa Core     1
# Name: count, Length: 233, dtype: int64

# %%
import re

def extract_cores(processor):
    match = re.search(r'\b(Single|Dual|Quad|Octa|Tru-Octa|Hexa|Deca|Nona)\s+core\b', processor, re.IGNORECASE)
    return match.group(0) if match else 'Other'

cores = df['processor'].apply(extract_cores)

# %%
df.insert(8, 'num_cores', cores)

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa core        1473
# Tru-Octa Core     248
# Quad core         211
# Other             175
# Hexa Core          74
# Dual core          25
# Dual Core          13
# Single Core        10
# Deca Core           6
# Quad Core           6
# Nona Core           5
# Single core         2
# Name: count, dtype: int64

# %%
core_mapping = {
    'Single Core': 1,
    'Single core': 1,
    'Dual Core': 2,
    'Dual core': 2,
    'Quad Core': 4,
    'Quad core': 4,
    'Hexa Core': 6,
    'Octa Core': 8,
    'Octa core': 8,
    'Tru-Octa Core': 8,
    'Deca Core': 10,
    'Nona Core': 9,
    'Other': np.nan
}

df['num_cores'] = df['num_cores'].replace(core_mapping)
# Out:
# C:\Users\DILKHUSH\AppData\Local\Temp\ipykernel_14872\3786327759.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['num_cores'] = df['num_cores'].replace(core_mapping)

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8.0     1721
# 4.0      217
# 6.0       74
# 2.0       38
# 1.0       12
# 10.0       6
# 9.0        5
# Name: count, dtype: int64

# %%
df['num_cores'].isna().sum()
# Out:
# 175

# %% [markdown]
# rear_cameras and front_cameras - need to do something. like one column can be created as total number of rear cameras,

# %%
df['rear_cameras'].value_counts()
# Out:
# rear_cameras
# 13 MP Rear Camera             257
# 8 MP Rear Camera              217
# 50+2 MP Rear Camera           115
# 5 MP Rear Camera              107
# 13+2 MP Rear Camera            84
#                              ...
# 50+50+50+50 MP Rear Camera      1
# 108+5 MP Rear Camera            1
# 48+2+2+2 MP Rear Camera         1
# 108+5+2 MP Rear Camera          1
# 21.5 MP Rear Camera             1
# Name: count, Length: 236, dtype: int64

# %%
def handle_cameras(cameras):
    megapixels = [float(mp) for mp in re.findall(r'\d+\.?\d*', cameras)]
    num_cameras = len(megapixels)
    main_camera = max(megapixels)
    return num_cameras, main_camera

num_rear_cameras, main_rear_cameras = zip(*df['rear_cameras'].map(handle_cameras))

# %%
df.columns
# Out:
# Index(['model_name', 'price', 'expert_rating', 'user_rating',
#        'avg_user_rating', 'num_ratings', 'processor', 'processor_brand',
#        'num_cores', 'rear_cameras', 'front_cameras', 'display',
#        'ram_internal_memory', 'battery', 'operating_system',
#        'additional_features'],
#       dtype='object')

# %%
df.insert(10, 'num_rear_cameras', num_rear_cameras)

# %%
df.insert(11, 'main_rear_camera', main_rear_cameras)

# %%
num_front_cameras, main_front_cameras = zip(*df['front_cameras'].map(handle_cameras))

# %%
df.insert(13, 'num_front_cameras', num_front_cameras)

# %%
df.insert(14, 'main_front_camera', main_front_cameras)

# %%
df
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 0                      vivo V40  34,999            NaN                     0
# 1                     OPPO K12x  12,999            NaN                     0
# 2                  vivo V40 Pro  49,999            8.2                     0
# 3       Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 4         Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2875                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2876              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2877         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2878  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2879       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#      avg_user_rating  num_ratings                               processor  \
# 0                NaN          NaN            Snapdragon 7 Gen 3 Octa core
# 1                NaN          NaN       MediaTek Dimensity 6300 Octa core
# 2                NaN          NaN  MediaTek Dimensity 9200 Plus Octa core
# 3                4.5      16900.0           Snapdragon 7s Gen 2 Octa core
# 4                4.3        383.0           Samsung Exynos 1380 Octa core
# ...              ...          ...                                     ...
# 2875             3.7         80.0                                MediaTek
# 2876             4.5      35900.0               HiSilicon Kirin Octa core
# 2877             3.0        772.0                      MediaTek Quad core
# 2878             3.8        195.0                      MediaTek Quad core
# 2879             3.9       1253.0                      MediaTek Quad core
#
#      processor_brand  num_cores             rear_cameras  num_rear_cameras  \
# 0         Snapdragon        8.0     50+50 MP Rear Camera                 2
# 1           MediaTek        8.0      32+2 MP Rear Camera                 2
# 2           MediaTek        8.0  50+50+50 MP Rear Camera                 3
# 3         Snapdragon        8.0     50+13 MP Rear Camera                 2
# 4            Samsung        8.0    50+8+2 MP Rear Camera                 3
# ...              ...        ...                      ...               ...
# 2875        MediaTek        NaN        13 MP Rear Camera                 1
# 2876           Other        8.0      12+2 MP Rear Camera                 2
# 2877        MediaTek        4.0         8 MP Rear Camera                 1
# 2878        MediaTek        4.0         8 MP Rear Camera                 1
# 2879        MediaTek        4.0         5 MP Rear Camera                 1
#
#       main_rear_camera       front_cameras  num_front_cameras  \
# 0                 50.0  50 MP Front Camera                  1
# 1                 32.0   8 MP Front Camera                  1
# 2                 50.0  50 MP Front Camera                  1
# 3                 50.0  32 MP Front Camera                  1
# 4                 50.0  13 MP Front Camera                  1
# ...                ...                 ...                ...
# 2875              13.0   5 MP Front Camera                  1
# 2876              12.0   8 MP Front Camera                  1
# 2877               8.0   2 MP Front Camera                  1
# 2878               8.0   5 MP Front Camera                  1
# 2879               5.0   5 MP Front Camera                  1
#
#       main_front_camera                                     display  \
# 0                  50.0       6.78″ (17.22 cm) 120Hz AMOLED Display
# 1                   8.0          6.67″ (16.94 cm) 120Hz LCD Display
# 2                  50.0       6.78″ (17.22 cm) 120Hz AMOLED Display
# 3                  32.0       6.67″ (16.94 cm) 144Hz P-OLED Display
# 4                  13.0  6.6″ (16.76 cm) 120Hz Super AMOLED Display
# ...                 ...                                         ...
# 2875                5.0              5.0″ (12.7 cm) IPS LCD Display
# 2876                8.0             5.5″ (13.97 cm) IPS LCD Display
# 2877                2.0              5.0″ (12.7 cm) IPS LCD Display
# 2878                5.0              5.0″ (12.7 cm) IPS LCD Display
# 2879                5.0             5.5″ (13.97 cm) IPS LCD Display
#
#             ram_internal_memory                       battery  \
# 0     8 GB RAM | 128 GB Storage  5500 mAh | 80W Fast Charging
# 1     6 GB RAM | 128 GB Storage  5100 mAh | 45W Fast Charging
# 2     8 GB RAM | 256 GB Storage  5500 mAh | 80W Fast Charging
# 3     8 GB RAM | 128 GB Storage  5000 mAh | 68W Fast Charging
# 4     6 GB RAM | 128 GB Storage  6000 mAh | 25W Fast Charging
# ...                         ...                           ...
# 2875   2 GB RAM | 16 GB Storage                      2500 mAh
# 2876   3 GB RAM | 32 GB Storage                      3340 mAh
# 2877   2 GB RAM | 16 GB Storage                      3000 mAh
# 2878    1 GB RAM | 8 GB Storage                      2300 mAh
# 2879   2 GB RAM | 16 GB Storage                      2800 mAh
#
#        operating_system            additional_features
# 0        Android v14 OS        5G | Fingerprint Sensor
# 1        Android v14 OS        5G | Fingerprint Sensor
# 2        Android v14 OS        5G | Fingerprint Sensor
# 3        Android v14 OS  5G | NFC | Fingerprint Sensor
# 4        Android v14 OS  5G | NFC | Fingerprint Sensor
# ...                 ...                            ...
# 2875    Android v6.0 OS                No add features
# 2876  Android v6.0.1 OS             Fingerprint Sensor
# 2877    Android v6.0 OS                No add features
# 2878    Android v6.0 OS                No add features
# 2879    Android v6.0 OS             Fingerprint Sensor
#
# [2248 rows x 20 columns]

# %% [markdown]
# display - can be split into size, refresh rate and type of display.

# %%
df['display'].value_counts()
# Out:
# display
# 5.0″ (12.7 cm) IPS LCD Display                 160
# 5.5″ (13.97 cm) IPS LCD Display                124
# 6.67″ (16.94 cm) 120Hz AMOLED Display           77
# 6.78″ (17.22 cm) 120Hz AMOLED Display           51
# 6.6″ (16.76 cm) 90Hz IPS LCD Display            40
#                                               ...
# 5.15″ (13.08 cm) IPS LCD Display                 1
# 5.8″ (14.73 cm) 60Hz Dynamic AMOLED Display      1
# 6.9″ (17.53 cm) 144Hz P-OLED Display             1
# 2.25″ (5.72 cm) TFT Display                      1
# 6.2″ (15.75 cm) P-OLED Display                   1
# Name: count, Length: 370, dtype: int64

# %%
display_size = df['display'].str.split(' ').str.get(0).str.replace('″', '')

# %%
df.insert(16, 'display_size', display_size)

# %%
refresh_rate = df['display'].str.split(' ').str.get(3)

# %%
df.insert(17, 'refresh_rate', refresh_rate)

# %%
display_type = df['display'].str.split(' ').str.get(-3) + ' ' + df['display'].str.split(' ').str.get(-2)

# %%
display_type.value_counts()
# Out:
# display
# IPS LCD               1153
# Super AMOLED           228
# 120Hz AMOLED           211
# cm) TFT                 85
# cm) AMOLED              59
# 90Hz AMOLED             54
# AMOLED 2x               43
# Fluid AMOLED            41
# 120Hz OLED              32
# cm) LCD                 31
# TFT LCD                 29
# PLS LCD                 27
# 60Hz OLED               26
# cm) OLED                22
# 60Hz AMOLED             21
# AMOLED Plus             20
# Dynamic AMOLED          18
# 144Hz AMOLED            15
# 144Hz P-OLED            14
# 120Hz LCD               13
# Flexible AMOLED         12
# 90Hz LCD                10
# LTPO AMOLED              9
# 120Hz P-OLED             7
# Optic AMOLED             7
# 90Hz OLED                7
# cm) S-LCD                7
# cm) P-OLED               5
# 90Hz TFT                 4
# S-LCD 3                  4
# LTPS LCD                 4
# S-LCD 5                  3
# IPS LED                  3
# 60Hz TFT                 3
# S-LCD 2                  3
# TFT LTPS                 3
# 120Hz TFT                2
# Flexi-fluid AMOLED       2
# 165Hz P-OLED             2
# Plus LCD                 1
# (8.89 cm)                1
# S-LCD 6                  1
# (13.97 cm)               1
# 90Hz P-OLED              1
# 60Hz LCD                 1
# 144Hz OLED               1
# LTPS AMOLED              1
# 60Hz P-OLED              1
# Name: count, dtype: int64

# %%
df.insert(18, 'display_type', display_type)

# %%
df
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 0                      vivo V40  34,999            NaN                     0
# 1                     OPPO K12x  12,999            NaN                     0
# 2                  vivo V40 Pro  49,999            8.2                     0
# 3       Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 4         Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2875                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2876              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2877         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2878  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2879       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#      avg_user_rating  num_ratings                               processor  \
# 0                NaN          NaN            Snapdragon 7 Gen 3 Octa core
# 1                NaN          NaN       MediaTek Dimensity 6300 Octa core
# 2                NaN          NaN  MediaTek Dimensity 9200 Plus Octa core
# 3                4.5      16900.0           Snapdragon 7s Gen 2 Octa core
# 4                4.3        383.0           Samsung Exynos 1380 Octa core
# ...              ...          ...                                     ...
# 2875             3.7         80.0                                MediaTek
# 2876             4.5      35900.0               HiSilicon Kirin Octa core
# 2877             3.0        772.0                      MediaTek Quad core
# 2878             3.8        195.0                      MediaTek Quad core
# 2879             3.9       1253.0                      MediaTek Quad core
#
#      processor_brand  num_cores             rear_cameras  ...  \
# 0         Snapdragon        8.0     50+50 MP Rear Camera  ...
# 1           MediaTek        8.0      32+2 MP Rear Camera  ...
# 2           MediaTek        8.0  50+50+50 MP Rear Camera  ...
# 3         Snapdragon        8.0     50+13 MP Rear Camera  ...
# 4            Samsung        8.0    50+8+2 MP Rear Camera  ...
# ...              ...        ...                      ...  ...
# 2875        MediaTek        NaN        13 MP Rear Camera  ...
# 2876           Other        8.0      12+2 MP Rear Camera  ...
# 2877        MediaTek        4.0         8 MP Rear Camera  ...
# 2878        MediaTek        4.0         8 MP Rear Camera  ...
# 2879        MediaTek        4.0         5 MP Rear Camera  ...
#
#       num_front_cameras  main_front_camera  \
# 0                     1               50.0
# 1                     1                8.0
# 2                     1               50.0
# 3                     1               32.0
# 4                     1               13.0
# ...                 ...                ...
# 2875                  1                5.0
# 2876                  1                8.0
# 2877                  1                2.0
# 2878                  1                5.0
# 2879                  1                5.0
#
#                                          display  display_size  refresh_rate  \
# 0          6.78″ (17.22 cm) 120Hz AMOLED Display          6.78         120Hz
# 1             6.67″ (16.94 cm) 120Hz LCD Display          6.67         120Hz
# 2          6.78″ (17.22 cm) 120Hz AMOLED Display          6.78         120Hz
# 3          6.67″ (16.94 cm) 144Hz P-OLED Display          6.67         144Hz
# 4     6.6″ (16.76 cm) 120Hz Super AMOLED Display           6.6         120Hz
# ...                                          ...           ...           ...
# 2875              5.0″ (12.7 cm) IPS LCD Display           5.0           IPS
# 2876             5.5″ (13.97 cm) IPS LCD Display           5.5           IPS
# 2877              5.0″ (12.7 cm) IPS LCD Display           5.0           IPS
# 2878              5.0″ (12.7 cm) IPS LCD Display           5.0           IPS
# 2879             5.5″ (13.97 cm) IPS LCD Display           5.5           IPS
#
#       display_type        ram_internal_memory                       battery  \
# 0     120Hz AMOLED  8 GB RAM | 128 GB Storage  5500 mAh | 80W Fast Charging
# 1        120Hz LCD  6 GB RAM | 128 GB Storage  5100 mAh | 45W Fast Charging
# 2     120Hz AMOLED  8 GB RAM | 256 GB Storage  5500 mAh | 80W Fast Charging
# 3     144Hz P-OLED  8 GB RAM | 128 GB Storage  5000 mAh | 68W Fast Charging
# 4     Super AMOLED  6 GB RAM | 128 GB Storage  6000 mAh | 25W Fast Charging
# ...            ...                        ...                           ...
# 2875       IPS LCD   2 GB RAM | 16 GB Storage                      2500 mAh
# 2876       IPS LCD   3 GB RAM | 32 GB Storage                      3340 mAh
# 2877       IPS LCD   2 GB RAM | 16 GB Storage                      3000 mAh
# 2878       IPS LCD    1 GB RAM | 8 GB Storage                      2300 mAh
# 2879       IPS LCD   2 GB RAM | 16 GB Storage                      2800 mAh
#
#        operating_system            additional_features
# 0        Android v14 OS        5G | Fingerprint Sensor
# 1        Android v14 OS        5G | Fingerprint Sensor
# 2        Android v14 OS        5G | Fingerprint Sensor
# 3        Android v14 OS  5G | NFC | Fingerprint Sensor
# 4        Android v14 OS  5G | NFC | Fingerprint Sensor
# ...                 ...                            ...
# 2875    Android v6.0 OS                No add features
# 2876  Android v6.0.1 OS             Fingerprint Sensor
# 2877    Android v6.0 OS                No add features
# 2878    Android v6.0 OS                No add features
# 2879    Android v6.0 OS             Fingerprint Sensor
#
# [2248 rows x 23 columns]

# %%
df['display_type'].value_counts().index.tolist()
# Out:
# ['IPS LCD',
#  'Super AMOLED',
#  '120Hz AMOLED',
#  'cm) TFT',
#  'cm) AMOLED',
#  '90Hz AMOLED',
#  'AMOLED 2x',
#  'Fluid AMOLED',
#  '120Hz OLED',
#  'cm) LCD',
#  'TFT LCD',
#  'PLS LCD',
#  '60Hz OLED',
#  'cm) OLED',
#  '60Hz AMOLED',
#  'AMOLED Plus',
#  'Dynamic AMOLED',
#  '144Hz AMOLED',
#  '144Hz P-OLED',
#  '120Hz LCD',
#  'Flexible AMOLED',
#  '90Hz LCD',
#  'LTPO AMOLED',
#  '120Hz P-OLED',
#  'Optic AMOLED',
#  '90Hz OLED',
#  'cm) S-LCD',
#  'cm) P-OLED',
#  '90Hz TFT',
#  'S-LCD 3',
#  'LTPS LCD',
#  'S-LCD 5',
#  'IPS LED',
#  '60Hz TFT',
#  'S-LCD 2',
#  'TFT LTPS',
#  '120Hz TFT',
#  'Flexi-fluid AMOLED',
#  '165Hz P-OLED',
#  'Plus LCD',
#  '(8.89 cm)',
#  'S-LCD 6',
#  '(13.97 cm)',
#  '90Hz P-OLED',
#  '60Hz LCD',
#  '144Hz OLED',
#  'LTPS AMOLED',
#  '60Hz P-OLED']

# %%
def display_type_categorize(display_type):
    if 'IPS LCD' in display_type:
        return 'IPS LCD'
    elif 'TFT LCD' in display_type:
        return 'TFT LCD'
    elif 'P-OLED' in display_type:
        return 'P-OLED'
    elif 'AMOLED' in display_type and 'Super AMOLED' not in display_type:
        return 'AMOLED'
    elif 'Super AMOLED' in display_type:
        return 'Super AMOLED'
    elif 'LED' in display_type:
        return 'OLED'
    elif 'LCD' in display_type:
        return 'IPS LCD'
    elif 'TFT' in display_type:
        return 'TFT LCD'
    else:
        return 'IPS LCD'

# %%
df['display_type'] = df['display_type'].apply(display_type_categorize)

# %%
df['display_type'].value_counts()
# Out:
# display_type
# IPS LCD         1260
# AMOLED           513
# Super AMOLED     228
# TFT LCD          126
# OLED              91
# P-OLED            30
# Name: count, dtype: int64

# %%
df['display_type'].isna().sum()
# Out:
# 0

# %% [markdown]
# ram_internal_memory - can be split into RAM and internal memory.

# %%
df['ram_internal_memory'].value_counts()
# Out:
# ram_internal_memory
# 8 GB RAM | 128 GB Storage      316
# 4 GB RAM | 64 GB Storage       292
# 6 GB RAM | 128 GB Storage      271
# 3 GB RAM | 32 GB Storage       172
# 8 GB RAM | 256 GB Storage      158
#                               ...
# 128 MB RAM | 50 MB Storage       1
# 512 MB RAM | 256 MB Storage      1
# 16 GB RAM | 1 TB Storage         1
# 384 MB RAM | 1 GB Storage        1
# 2 GB RAM | 256 GB Storage        1
# Name: count, Length: 62, dtype: int64

# %%
# can't extract by this way because some mobiles has only storage and no ram value
df['ram_internal_memory'].str.split('|').str.get(0).str.strip().str.split(' ').loc[2421]
# Out:
# ['200', 'MB', 'Storage']

# %%
ram = df['ram_internal_memory'].str.extract(r'(\d+ MB|\d+ GB) RAM')[0]
storage = df['ram_internal_memory'].str.extract(r'(\d+ MB|\d+ GB|\d+ TB) Storage')[0]

# %%
df.insert(20, 'ram', ram)
df.insert(21, 'storage', storage)

# %%
df['ram'].value_counts()
# Out:
# ram
# 8 GB      481
# 4 GB      465
# 6 GB      358
# 3 GB      261
# 2 GB      232
# 1 GB      190
# 12 GB     173
# 512 MB     46
# 16 GB      14
# 5 GB        9
# 256 MB      5
# 128 MB      4
# 768 MB      3
# 18 GB       2
# 10 GB       1
# 384 MB      1
# Name: count, dtype: int64

# %%
df['ram'].isna().sum()
# Out:
# 3

# %%
df[df['ram'].isna()]
# Out:
#                     model_name   price  expert_rating         user_rating  \
# 1597  Blackberry Pearl 3G 9105  20,990            NaN   3.1 ★\n94 Ratings
# 2421                  Nokia C6   9,655            NaN  2.3 ★\n106 Ratings
# 2422                  Nokia E5   8,231            NaN  5.0 ★\n366 Ratings
#
#      avg_user_rating  num_ratings    processor processor_brand  num_cores  \
# 1597             3.1         94.0  Single Core           Other        1.0
# 2421             2.3        106.0  Single Core           Other        1.0
# 2422             5.0        366.0  Single Core           Other        1.0
#
#             rear_cameras  ...                      display  display_size  \
# 1597  3.2 MP Rear Camera  ...  2.25″ (5.72 cm) TFT Display          2.25
# 2421    5 MP Rear Camera  ...   3.2″ (8.13 cm) LCD Display           3.2
# 2422    5 MP Rear Camera  ...    2.4″ (6.1 cm) LCD Display           2.4
#
#      refresh_rate  display_type  ram_internal_memory  ram storage  \
# 1597          TFT       TFT LCD       256 MB Storage  NaN  256 MB
# 2421          LCD       IPS LCD       200 MB Storage  NaN  200 MB
# 2422          LCD       IPS LCD       256 MB Storage  NaN  256 MB
#
#                battery      operating_system additional_features
# 1597  1150 mAh Battery  Blackberry v5.0.x OS     No add features
# 2421  1200 mAh Battery            Symbian OS     No add features
# 2422  1200 mAh Battery            Symbian OS     No add features
#
# [3 rows x 25 columns]

# %%
df.loc[[1597, 2421, 2422], 'ram'] = '256 MB'

# %%
df['ram'].isna().sum()
# Out:
# 0

# %%
df['storage'].value_counts()
# Out:
# storage
# 128 GB    718
# 64 GB     410
# 256 GB    322
# 32 GB     267
# 16 GB     215
# 8 GB      160
# 4 GB       65
# 512 GB     57
# 1 TB       12
# 1 GB        5
# 256 MB      5
# 512 MB      5
# 9 GB        2
# 50 MB       1
# 200 MB      1
# 40 MB       1
# 157 MB      1
# Name: count, dtype: int64

# %%
df['storage'].isna().sum()
# Out:
# 1

# %%
df[df['storage'].isna()]
# Out:
#                 model_name  price  expert_rating        user_rating  \
# 2447  Micromax Bling 3 A86  6,000            NaN  3.5 ★\n32 Ratings
#
#      avg_user_rating  num_ratings  processor processor_brand  num_cores  \
# 2447             3.5         32.0  Dual Core           Other        2.0
#
#           rear_cameras  ...                    display  display_size  \
# 2447  5 MP Rear Camera  ...  4″ (10.16 cm) TFT Display             4
#
#      refresh_rate  display_type  ram_internal_memory     ram storage  \
# 2447          TFT       TFT LCD           512 MB RAM  512 MB     NaN
#
#                battery operating_system additional_features
# 2447  1600 mAh Battery  Android v4.1 OS     No add features
#
# [1 rows x 25 columns]

# %%
df.loc[2447, 'storage'] = '512 MB'

# %%
def convert_to_gb(storage):
    if 'TB' in storage:
        return float(storage.split()[0]) * 1024
    elif 'GB' in storage:
        return float(storage.split()[0])
    elif 'MB' in storage:
        return float(storage.split()[0]) / 1024
    return 0

# %%
df['ram'] = df['ram'].apply(convert_to_gb)
df['storage'] = df['storage'].apply(convert_to_gb)

# %% [markdown]
# battery - can be split into battery capacity and charging.

# %%
df['battery'].value_counts()
# Out:
# battery
# 5000 mAh | 18W Fast Charging    145
# 5000 mAh | 33W Fast Charging    121
# 5000 mAh | 10W                  119
# 3000 mAh                         94
# 4000 mAh                         68
#                                ...
# 6300 mAh                          1
# 4350 mAh | 65W Fast Charging      1
# 3095 mAh | 20W Fast Charging      1
# 6300 mAh Battery                  1
# 2610 mAh                          1
# Name: count, Length: 406, dtype: int64

# %%
battery_capacity = df['battery'].str.split('|').str.get(0).str.strip().str.split(' ').str.get(0)

# %%
df.insert(23, 'battery_capacity', battery_capacity)

# %%
df['battery_capacity'].value_counts()
# Out:
# battery_capacity
# 5000    751
# 4000    138
# 3000    119
# 6000    118
# 4500    104
#        ...
# 5700      1
# 2850      1
# 4492      1
# 4440      1
# 2610      1
# Name: count, Length: 221, dtype: int64

# %%
df['battery_capacity'].isna().sum()
# Out:
# 0

# %%
charging = df['battery'].str.split('|').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('W', '')

# %%
df.insert(24, 'charging', charging)

# %%
df['charging'].value_counts()
# Out:
# charging
# 18      207
# 33      176
# 10      156
# 25      115
# 15      102
# 20       77
# 67       69
# 30       68
# 45       61
# 44       49
# 80       42
# 65       42
# 120      42
# 66       29
# 100      23
# 68       10
# 50       10
# 27        7
# 90        6
# 150       6
# 55        6
# 125       5
# 22.5      4
# 70        3
# 60        2
# 35        1
# 180       1
# 24        1
# 7.5       1
# Name: count, dtype: int64

# %%
df['charging'].isna().sum()
# Out:
# 927

# %% [markdown]
# additional_features - can be split into has_5g, has_nfc, has_fingerprint_sensor

# %%
df['additional_features'].value_counts()
# Out:
# additional_features
# Fingerprint Sensor               737
# No add features                  494
# 5G | Fingerprint Sensor          340
# 5G | NFC | Fingerprint Sensor    331
# NFC | Fingerprint Sensor         234
# NFC                               68
# 5G | NFC                          44
# Name: count, dtype: int64

# %%
def add_feature_extract(value):
    has_fingerprint_sensor = 'Fingerprint Sensor' in value
    has_5g = '5G' in value
    has_nfc = 'NFC' in value
    
    return pd.Series([has_fingerprint_sensor, has_5g, has_nfc])

# %%
df[['has_fingerprint', 'has_5g', 'has_nfc']] = df['additional_features'].apply(add_feature_extract)

# %%
df
# Out:
#                      model_name   price  expert_rating           user_rating  \
# 0                      vivo V40  34,999            NaN                     0
# 1                     OPPO K12x  12,999            NaN                     0
# 2                  vivo V40 Pro  49,999            8.2                     0
# 3       Motorola Edge 50 Fusion  24,879            8.1  4.5 ★\n16.9K Ratings
# 4         Samsung Galaxy M35 5G  19,999            NaN    4.3 ★\n383 Ratings
# ...                         ...     ...            ...                   ...
# 2875                 LG K8 2017   8,999            NaN     3.7 ★\n80 Ratings
# 2876              Honor 6X 32GB  11,999            8.3  4.5 ★\n35.9K Ratings
# 2877         Videocon Delite 21   6,153            NaN    3.0 ★\n772 Ratings
# 2878  Karbonn Titanium Vista 4G   5,986            NaN    3.8 ★\n195 Ratings
# 2879       Karbonn Aura Note 4G   6,939            NaN  3.9 ★\n1,253 Ratings
#
#      avg_user_rating  num_ratings                               processor  \
# 0                NaN          NaN            Snapdragon 7 Gen 3 Octa core
# 1                NaN          NaN       MediaTek Dimensity 6300 Octa core
# 2                NaN          NaN  MediaTek Dimensity 9200 Plus Octa core
# 3                4.5      16900.0           Snapdragon 7s Gen 2 Octa core
# 4                4.3        383.0           Samsung Exynos 1380 Octa core
# ...              ...          ...                                     ...
# 2875             3.7         80.0                                MediaTek
# 2876             4.5      35900.0               HiSilicon Kirin Octa core
# 2877             3.0        772.0                      MediaTek Quad core
# 2878             3.8        195.0                      MediaTek Quad core
# 2879             3.9       1253.0                      MediaTek Quad core
#
#      processor_brand  num_cores             rear_cameras  ...  ram  storage  \
# 0         Snapdragon        8.0     50+50 MP Rear Camera  ...  8.0    128.0
# 1           MediaTek        8.0      32+2 MP Rear Camera  ...  6.0    128.0
# 2           MediaTek        8.0  50+50+50 MP Rear Camera  ...  8.0    256.0
# 3         Snapdragon        8.0     50+13 MP Rear Camera  ...  8.0    128.0
# 4            Samsung        8.0    50+8+2 MP Rear Camera  ...  6.0    128.0
# ...              ...        ...                      ...  ...  ...      ...
# 2875        MediaTek        NaN        13 MP Rear Camera  ...  2.0     16.0
# 2876           Other        8.0      12+2 MP Rear Camera  ...  3.0     32.0
# 2877        MediaTek        4.0         8 MP Rear Camera  ...  2.0     16.0
# 2878        MediaTek        4.0         8 MP Rear Camera  ...  1.0      8.0
# 2879        MediaTek        4.0         5 MP Rear Camera  ...  2.0     16.0
#
#                            battery  battery_capacity  charging  \
# 0     5500 mAh | 80W Fast Charging              5500        80
# 1     5100 mAh | 45W Fast Charging              5100        45
# 2     5500 mAh | 80W Fast Charging              5500        80
# 3     5000 mAh | 68W Fast Charging              5000        68
# 4     6000 mAh | 25W Fast Charging              6000        25
# ...                            ...               ...       ...
# 2875                      2500 mAh              2500       NaN
# 2876                      3340 mAh              3340       NaN
# 2877                      3000 mAh              3000       NaN
# 2878                      2300 mAh              2300       NaN
# 2879                      2800 mAh              2800       NaN
#
#        operating_system            additional_features has_fingerprint has_5g  \
# 0        Android v14 OS        5G | Fingerprint Sensor            True   True
# 1        Android v14 OS        5G | Fingerprint Sensor            True   True
# 2        Android v14 OS        5G | Fingerprint Sensor            True   True
# 3        Android v14 OS  5G | NFC | Fingerprint Sensor            True   True
# 4        Android v14 OS  5G | NFC | Fingerprint Sensor            True   True
# ...                 ...                            ...             ...    ...
# 2875    Android v6.0 OS                No add features           False  False
# 2876  Android v6.0.1 OS             Fingerprint Sensor            True  False
# 2877    Android v6.0 OS                No add features           False  False
# 2878    Android v6.0 OS                No add features           False  False
# 2879    Android v6.0 OS             Fingerprint Sensor            True  False
#
#      has_nfc
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
# ...      ...
# 2875   False
# 2876   False
# 2877   False
# 2878   False
# 2879   False
#
# [2248 rows x 30 columns]

# %% [markdown]
# model_name - another col 'brand_name' can be created.

# %%
brand_name = df['model_name'].str.split(' ').str.get(0)

# %%
brand_name.value_counts()
# there is two issues:
# 1. I Kall is a brand but only I is fetched.
# 2. most Motorola phones has only moto word that have to handled separately.
# Out:
# model_name
# Samsung      312
# realme       210
# vivo         195
# Xiaomi       194
# OPPO         130
#             ...
# Lephone        1
# Mobiistar      1
# Comio          1
# Elephone       1
# Nextbit        1
# Name: count, Length: 63, dtype: int64

# %%
brand_name = brand_name.str.replace('^I$', 'I Kall', regex=True).str.replace('^Moto$', 'Motorola', regex=True)

# %%
brand_name[brand_name.str.contains('Moto')].value_counts()
# Out:
# model_name
# Motorola    94
# Name: count, dtype: int64

# %%
df.insert(1, 'brand', brand_name)

# %%
df
# Out:
#                      model_name     brand   price  expert_rating  \
# 0                      vivo V40      vivo  34,999            NaN
# 1                     OPPO K12x      OPPO  12,999            NaN
# 2                  vivo V40 Pro      vivo  49,999            8.2
# 3       Motorola Edge 50 Fusion  Motorola  24,879            8.1
# 4         Samsung Galaxy M35 5G   Samsung  19,999            NaN
# ...                         ...       ...     ...            ...
# 2875                 LG K8 2017        LG   8,999            NaN
# 2876              Honor 6X 32GB     Honor  11,999            8.3
# 2877         Videocon Delite 21  Videocon   6,153            NaN
# 2878  Karbonn Titanium Vista 4G   Karbonn   5,986            NaN
# 2879       Karbonn Aura Note 4G   Karbonn   6,939            NaN
#
#                user_rating avg_user_rating  num_ratings  \
# 0                        0             NaN          NaN
# 1                        0             NaN          NaN
# 2                        0             NaN          NaN
# 3     4.5 ★\n16.9K Ratings             4.5      16900.0
# 4       4.3 ★\n383 Ratings             4.3        383.0
# ...                    ...             ...          ...
# 2875     3.7 ★\n80 Ratings             3.7         80.0
# 2876  4.5 ★\n35.9K Ratings             4.5      35900.0
# 2877    3.0 ★\n772 Ratings             3.0        772.0
# 2878    3.8 ★\n195 Ratings             3.8        195.0
# 2879  3.9 ★\n1,253 Ratings             3.9       1253.0
#
#                                    processor processor_brand  num_cores  ...  \
# 0               Snapdragon 7 Gen 3 Octa core      Snapdragon        8.0  ...
# 1          MediaTek Dimensity 6300 Octa core        MediaTek        8.0  ...
# 2     MediaTek Dimensity 9200 Plus Octa core        MediaTek        8.0  ...
# 3              Snapdragon 7s Gen 2 Octa core      Snapdragon        8.0  ...
# 4              Samsung Exynos 1380 Octa core         Samsung        8.0  ...
# ...                                      ...             ...        ...  ...
# 2875                                MediaTek        MediaTek        NaN  ...
# 2876               HiSilicon Kirin Octa core           Other        8.0  ...
# 2877                      MediaTek Quad core        MediaTek        4.0  ...
# 2878                      MediaTek Quad core        MediaTek        4.0  ...
# 2879                      MediaTek Quad core        MediaTek        4.0  ...
#
#       ram  storage                       battery battery_capacity  charging  \
# 0     8.0    128.0  5500 mAh | 80W Fast Charging             5500        80
# 1     6.0    128.0  5100 mAh | 45W Fast Charging             5100        45
# 2     8.0    256.0  5500 mAh | 80W Fast Charging             5500        80
# 3     8.0    128.0  5000 mAh | 68W Fast Charging             5000        68
# 4     6.0    128.0  6000 mAh | 25W Fast Charging             6000        25
# ...   ...      ...                           ...              ...       ...
# 2875  2.0     16.0                      2500 mAh             2500       NaN
# 2876  3.0     32.0                      3340 mAh             3340       NaN
# 2877  2.0     16.0                      3000 mAh             3000       NaN
# 2878  1.0      8.0                      2300 mAh             2300       NaN
# 2879  2.0     16.0                      2800 mAh             2800       NaN
#
#        operating_system            additional_features has_fingerprint has_5g  \
# 0        Android v14 OS        5G | Fingerprint Sensor            True   True
# 1        Android v14 OS        5G | Fingerprint Sensor            True   True
# 2        Android v14 OS        5G | Fingerprint Sensor            True   True
# 3        Android v14 OS  5G | NFC | Fingerprint Sensor            True   True
# 4        Android v14 OS  5G | NFC | Fingerprint Sensor            True   True
# ...                 ...                            ...             ...    ...
# 2875    Android v6.0 OS                No add features           False  False
# 2876  Android v6.0.1 OS             Fingerprint Sensor            True  False
# 2877    Android v6.0 OS                No add features           False  False
# 2878    Android v6.0 OS                No add features           False  False
# 2879    Android v6.0 OS             Fingerprint Sensor            True  False
#
#      has_nfc
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
# ...      ...
# 2875   False
# 2876   False
# 2877   False
# 2878   False
# 2879   False
#
# [2248 rows x 31 columns]

# %% [markdown]
# operating_system - split into two cols os_type, os_version

# %%
df['operating_system'].value_counts()
# Out:
# operating_system
# Android v11 OS           294
# Android v13 OS           290
# Android v12 OS           238
# Android v10 OS           211
# Android v14 OS           210
#                         ...
# Android v4.0.4 OS          1
# Blackberry v10.2 OS        1
# Blackberry v10.3.1 OS      1
# Pragati OS OS              1
# Sailfish OS v2.0 OS        1
# Name: count, Length: 69, dtype: int64

# %%
os_type = df['operating_system'].str.split(' ').str.get(0)

# %%
os_type.value_counts()
# Out:
# operating_system
# Android       2128
# iOS             88
# Blackberry       9
# Windows          9
# Symbian          9
# Tizen            2
# Pragati          1
# KAI              1
# Sailfish         1
# Name: count, dtype: int64

# %%
os_type.value_counts().head(2).index.tolist()
# Out:
# ['Android', 'iOS']

# %%
top_os = os_type.value_counts().head(2).index.tolist()
os_type = os_type.apply(lambda x: x if x in top_os else 'Other')

# %%
os_type.value_counts()
# Out:
# operating_system
# Android    2128
# iOS          88
# Other        32
# Name: count, dtype: int64

# %%
df.insert(27, 'os_type', os_type)

# %%
os_version = df['operating_system'].str.extract(r'(v[\d\.]+)')

# %%
df.insert(28, 'os_version', os_version)

# %%
df['os_version'].isna().sum()
# Out:
# 12

# %%
df[df['os_version'].isna()]
# Out:
#                   model_name     brand   price  expert_rating  \
# 432   Reliance JioPhone Next  Reliance   5,599            7.0
# 2019        Oukitel WP20 Pro   Oukitel  16,499            NaN
# 2128           Nokia 8110 4G     Nokia   5,999            7.0
# 2280         Nokia C5-00 5MP     Nokia   6,599            NaN
# 2406      Nokia 808 PureView     Nokia  34,499            NaN
# 2420                Nokia C5     Nokia   6,599            NaN
# 2421                Nokia C6     Nokia   9,655            NaN
# 2422                Nokia E5     Nokia   8,231            NaN
# 2423             Nokia C5-03     Nokia   7,920            NaN
# 2424                Nokia E6     Nokia  16,546            NaN
# 2425          Nokia 500 Fate     Nokia   5,209            NaN
# 2426             Nokia C5-05     Nokia   9,315            NaN
#
#                user_rating avg_user_rating  num_ratings  \
# 432   3.7 ★\n1,630 Ratings             3.7       1630.0
# 2019     4.4 ★\n30 Ratings             4.4         30.0
# 2128  1.0 ★\n3,286 Ratings             1.0       3286.0
# 2280     2.7 ★\n25 Ratings             2.7         25.0
# 2406    3.9 ★\n574 Ratings             3.9        574.0
# 2420    4.0 ★\n247 Ratings             4.0        247.0
# 2421    2.3 ★\n106 Ratings             2.3        106.0
# 2422    5.0 ★\n366 Ratings             5.0        366.0
# 2423    1.0 ★\n137 Ratings             1.0        137.0
# 2424    4.8 ★\n189 Ratings             4.8        189.0
# 2425    4.0 ★\n300 Ratings             4.0        300.0
# 2426    3.8 ★\n181 Ratings             3.8        181.0
#
#                          processor processor_brand  num_cores  ...  \
# 432       Snapdragon 215 Quad core      Snapdragon        4.0  ...
# 2019  MediaTek Helio P22 Octa core        MediaTek        8.0  ...
# 2128      Snapdragon 205 Dual core      Snapdragon        2.0  ...
# 2280                     Dual Core           Other        2.0  ...
# 2406                     Dual Core           Other        2.0  ...
# 2420                   Single Core           Other        1.0  ...
# 2421                   Single Core           Other        1.0  ...
# 2422                   Single Core           Other        1.0  ...
# 2423                   Single Core           Other        1.0  ...
# 2424                   Single Core           Other        1.0  ...
# 2425                   Single Core           Other        1.0  ...
# 2426                   Single Core           Other        1.0  ...
#
#                battery  battery_capacity  charging operating_system  os_type  \
# 432           3500 mAh              3500       NaN    Pragati OS OS    Other
# 2019          6300 mAh              6300       NaN       Android OS  Android
# 2128          1500 mAh              1500       NaN        KAI OS OS    Other
# 2280  1050 mAh Battery              1050       NaN       Symbian OS    Other
# 2406  1400 mAh Battery              1400       NaN       Symbian OS    Other
# 2420   860 mAh Battery               860       NaN       Symbian OS    Other
# 2421  1200 mAh Battery              1200       NaN       Symbian OS    Other
# 2422  1200 mAh Battery              1200       NaN       Symbian OS    Other
# 2423  1000 mAh Battery              1000       NaN       Symbian OS    Other
# 2424  1500 mAh Battery              1500       NaN       Symbian OS    Other
# 2425  1110 mAh Battery              1110       NaN       Symbian OS    Other
# 2426  1000 mAh Battery              1000       NaN       Symbian OS    Other
#
#       os_version       additional_features has_fingerprint has_5g has_nfc
# 432          NaN           No add features           False  False   False
# 2019         NaN  NFC | Fingerprint Sensor            True  False    True
# 2128         NaN           No add features           False  False   False
# 2280         NaN           No add features           False  False   False
# 2406         NaN           No add features           False  False   False
# 2420         NaN           No add features           False  False   False
# 2421         NaN           No add features           False  False   False
# 2422         NaN           No add features           False  False   False
# 2423         NaN           No add features           False  False   False
# 2424         NaN           No add features           False  False   False
# 2425         NaN           No add features           False  False   False
# 2426         NaN           No add features           False  False   False
#
# [12 rows x 33 columns]

# %%
df.loc[[432, 2019, 2128, 2280, 2406, 2420, 2421, 2422, 2423, 2424, 2425, 2426], 'os_version'] = ['v11', 'v12', 'v2.5.1', 'v9.3', 'v9.3', 'v9.3', 'v9.4', 'v9.3', 'v9.4', 'v9.3', 'v9.3', 'v9.4']

# %%
df['os_version'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Handling validity issues

# %% [markdown]
# price - has ',' between numbers. `validity`

# %%
df['price'] = df['price'].str.replace(',', '')

# %%
df.isna().sum()
# Out:
# model_name               0
# brand                    0
# price                    0
# expert_rating          850
# user_rating              0
# avg_user_rating         69
# num_ratings             69
# processor                0
# processor_brand          0
# num_cores              175
# rear_cameras             0
# num_rear_cameras         0
# main_rear_camera         0
# front_cameras            0
# num_front_cameras        0
# main_front_camera        0
# display                  0
# display_size             0
# refresh_rate             0
# display_type             0
# ram_internal_memory      0
# ram                      0
# storage                  0
# battery                  0
# battery_capacity         0
# charging               927
# operating_system         0
# os_type                  0
# os_version               0
# additional_features      0
# has_fingerprint          0
# has_5g                   0
# has_nfc                  0
# dtype: int64

# %%
df[df['num_cores'].isna()]
# Out:
#                       model_name       brand  price  expert_rating  \
# 915           Blackberry Classic  Blackberry  14999            NaN
# 940                   XOLO Q3000        XOLO  15399            NaN
# 1257               Blackberry Q5  Blackberry  20240            NaN
# 1410  Sony Ericsson Xperia Neo V        Sony  19299            NaN
# 1414            Sony Xperia tipo        Sony   6299            NaN
# ...                          ...         ...    ...            ...
# 2804         Panasonic Eluga Arc   Panasonic   8097            NaN
# 2842                Lenovo A7700      Lenovo   7400            NaN
# 2845           Lenovo A6600 Plus      Lenovo   6099            6.8
# 2857        Panasonic Eluga Tapp   Panasonic   6500            NaN
# 2875                  LG K8 2017          LG   8999            NaN
#
#                user_rating avg_user_rating  num_ratings           processor  \
# 915     5.0 ★\n358 Ratings             5.0        358.0  Snapdragon S4 Plus
# 940     4.3 ★\n833 Ratings             4.3        833.0            MediaTek
# 1257  3.0 ★\n1,107 Ratings             3.0       1107.0      Snapdragon 400
# 1410    4.6 ★\n753 Ratings             4.6        753.0       Snapdragon S2
# 1414  4.8 ★\n2,293 Ratings             4.8       2293.0          Snapdragon
# ...                    ...             ...          ...                 ...
# 2804    3.5 ★\n335 Ratings             3.5        335.0      Snapdragon 410
# 2842  4.0 ★\n1,140 Ratings             4.0       1140.0            MediaTek
# 2845  3.9 ★\n1,521 Ratings             3.9       1521.0            MediaTek
# 2857  1.0 ★\n2,820 Ratings             1.0       2820.0            MediaTek
# 2875     3.7 ★\n80 Ratings             3.7         80.0            MediaTek
#
#      processor_brand  num_cores  ...           battery  battery_capacity  \
# 915       Snapdragon        NaN  ...  2515 mAh Battery              2515
# 940         MediaTek        NaN  ...  4000 mAh Battery              4000
# 1257      Snapdragon        NaN  ...  2180 mAh Battery              2180
# 1410      Snapdragon        NaN  ...  1500 mAh Battery              1500
# 1414      Snapdragon        NaN  ...  1500 mAh Battery              1500
# ...              ...        ...  ...               ...               ...
# 2804      Snapdragon        NaN  ...          1800 mAh              1800
# 2842        MediaTek        NaN  ...          2900 mAh              2900
# 2845        MediaTek        NaN  ...          2300 mAh              2300
# 2857        MediaTek        NaN  ...          2800 mAh              2800
# 2875        MediaTek        NaN  ...          2500 mAh              2500
#
#       charging       operating_system  os_type  os_version  \
# 915        NaN  Blackberry v10.3.1 OS    Other     v10.3.1
# 940        NaN        Android v4.2 OS  Android        v4.2
# 1257       NaN    Blackberry v10.2 OS    Other       v10.2
# 1410       NaN        Android v2.3 OS  Android        v2.3
# 1414       NaN      Android v4.0.4 OS  Android      v4.0.4
# ...        ...                    ...      ...         ...
# 2804       NaN        Android v5.1 OS  Android        v5.1
# 2842       NaN        Android v6.0 OS  Android        v6.0
# 2845       NaN        Android v6.0 OS  Android        v6.0
# 2857       NaN        Android v6.0 OS  Android        v6.0
# 2875       NaN        Android v6.0 OS  Android        v6.0
#
#      additional_features has_fingerprint has_5g has_nfc
# 915      No add features           False  False   False
# 940      No add features           False  False   False
# 1257                 NFC           False  False    True
# 1410     No add features           False  False   False
# 1414     No add features           False  False   False
# ...                  ...             ...    ...     ...
# 2804  Fingerprint Sensor            True  False   False
# 2842     No add features           False  False   False
# 2845     No add features           False  False   False
# 2857  Fingerprint Sensor            True  False   False
# 2875     No add features           False  False   False
#
# [175 rows x 33 columns]

# %%
num_cores = pd.to_numeric(df['num_cores'], errors='coerce')
num_cores.median()
# Out:
# 8.0

# %%
num_cores.mode()
# Out:
# 0    8.0
# Name: num_cores, dtype: float64

# %% [markdown]
# On searching on internet, I found that some of them are quad core and some are octa core.

# %%
df[df['charging'].isna()]
# Out:
#                      model_name     brand  price  expert_rating  \
# 261                    OPPO A18      OPPO   8999            7.6
# 355                   I Kall S1    I Kall   9499            NaN
# 432      Reliance JioPhone Next  Reliance   5599            7.0
# 435               Tecno Spark 9     Tecno   6699            7.2
# 475                    OPPO A16      OPPO  10499            7.0
# ...                         ...       ...    ...            ...
# 2875                 LG K8 2017        LG   8999            NaN
# 2876              Honor 6X 32GB     Honor  11999            8.3
# 2877         Videocon Delite 21  Videocon   6153            NaN
# 2878  Karbonn Titanium Vista 4G   Karbonn   5986            NaN
# 2879       Karbonn Aura Note 4G   Karbonn   6939            NaN
#
#                user_rating avg_user_rating  num_ratings  \
# 261   4.3 ★\n1,585 Ratings             4.3       1585.0
# 355      2.6 ★\n48 Ratings             2.6         48.0
# 432   3.7 ★\n1,630 Ratings             3.7       1630.0
# 435   3.9 ★\n7,802 Ratings             3.9       7802.0
# 475   4.3 ★\n5,055 Ratings             4.3       5055.0
# ...                    ...             ...          ...
# 2875     3.7 ★\n80 Ratings             3.7         80.0
# 2876  4.5 ★\n35.9K Ratings             4.5      35900.0
# 2877    3.0 ★\n772 Ratings             3.0        772.0
# 2878    3.8 ★\n195 Ratings             3.8        195.0
# 2879  3.9 ★\n1,253 Ratings             3.9       1253.0
#
#                          processor processor_brand  num_cores  ...   battery  \
# 261   MediaTek Helio G85 Octa core        MediaTek        8.0  ...  5000 mAh
# 355               Unisoc Octa core          Unisoc        8.0  ...  6000 mAh
# 432       Snapdragon 215 Quad core      Snapdragon        4.0  ...  3500 mAh
# 435   MediaTek Helio G37 Octa core        MediaTek        8.0  ...  5000 mAh
# 475   MediaTek Helio G35 Octa core        MediaTek        8.0  ...  5000 mAh
# ...                            ...             ...        ...  ...       ...
# 2875                      MediaTek        MediaTek        NaN  ...  2500 mAh
# 2876     HiSilicon Kirin Octa core           Other        8.0  ...  3340 mAh
# 2877            MediaTek Quad core        MediaTek        4.0  ...  3000 mAh
# 2878            MediaTek Quad core        MediaTek        4.0  ...  2300 mAh
# 2879            MediaTek Quad core        MediaTek        4.0  ...  2800 mAh
#
#       battery_capacity  charging   operating_system  os_type  os_version  \
# 261               5000       NaN     Android v13 OS  Android         v13
# 355               6000       NaN     Android v13 OS  Android         v13
# 432               3500       NaN      Pragati OS OS    Other         v11
# 435               5000       NaN     Android v12 OS  Android         v12
# 475               5000       NaN     Android v11 OS  Android         v11
# ...                ...       ...                ...      ...         ...
# 2875              2500       NaN    Android v6.0 OS  Android        v6.0
# 2876              3340       NaN  Android v6.0.1 OS  Android      v6.0.1
# 2877              3000       NaN    Android v6.0 OS  Android        v6.0
# 2878              2300       NaN    Android v6.0 OS  Android        v6.0
# 2879              2800       NaN    Android v6.0 OS  Android        v6.0
#
#      additional_features has_fingerprint has_5g has_nfc
# 261   Fingerprint Sensor            True  False   False
# 355   Fingerprint Sensor            True  False   False
# 432      No add features           False  False   False
# 435   Fingerprint Sensor            True  False   False
# 475   Fingerprint Sensor            True  False   False
# ...                  ...             ...    ...     ...
# 2875     No add features           False  False   False
# 2876  Fingerprint Sensor            True  False   False
# 2877     No add features           False  False   False
# 2878     No add features           False  False   False
# 2879  Fingerprint Sensor            True  False   False
#
# [927 rows x 33 columns]

# %%
charger_wattage = pd.to_numeric(df['charging'], errors='coerce')
charger_wattage.median()
# Out:
# 25.0

# %%
charger_wattage.mode()
# lets have them missing
# Out:
# 0    18.0
# Name: charging, dtype: float64

# %% [markdown]
# #### Extract num_high_resolution_cameras
# Before dropping cameras data, we can also extract important info that is the number of high_resoulation_cameras, which is generally the number of cameras which has MP higher or equal than the average of MP of all cameras

# %%
def handle_high_res_cameras(cameras):
    megapixels = [float(mp) for mp in re.findall(r'\d+\.?\d*', cameras)]
    mean_mp = np.mean(megapixels)
    num_high_resolution_cameras = sum(mp >= mean_mp for mp in megapixels)
    
    return num_high_resolution_cameras

num_high_resolution_cameras = df['rear_cameras'].map(handle_high_res_cameras)

# %%
df.insert(13, 'num_high_resolution_cameras', num_high_resolution_cameras)

# %%
df.head(10)
# Out:
#                 model_name     brand  price  expert_rating  \
# 0                 vivo V40      vivo  34999            NaN
# 1                OPPO K12x      OPPO  12999            NaN
# 2             vivo V40 Pro      vivo  49999            8.2
# 3  Motorola Edge 50 Fusion  Motorola  24879            8.1
# 4    Samsung Galaxy M35 5G   Samsung  19999            NaN
# 5     OnePlus Nord CE 4 5G   OnePlus  24998            8.2
# 6                 Moto G85  Motorola  18880            NaN
# 7           OnePlus Nord 4   OnePlus  29998            NaN
# 8  Motorola Edge 50 Pro 5G  Motorola  29495            8.4
# 9                 vivo V30      vivo  27999            8.2
#
#             user_rating avg_user_rating  num_ratings  \
# 0                     0             NaN          NaN
# 1                     0             NaN          NaN
# 2                     0             NaN          NaN
# 3  4.5 ★\n16.9K Ratings             4.5      16900.0
# 4    4.3 ★\n383 Ratings             4.3        383.0
# 5  4.2 ★\n3,455 Ratings             4.2       3455.0
# 6                     0             NaN          NaN
# 7                     0             NaN          NaN
# 8  4.4 ★\n17.5K Ratings             4.4      17500.0
# 9  4.5 ★\n4,803 Ratings             4.5       4803.0
#
#                                 processor processor_brand  num_cores  \
# 0            Snapdragon 7 Gen 3 Octa core      Snapdragon        8.0
# 1       MediaTek Dimensity 6300 Octa core        MediaTek        8.0
# 2  MediaTek Dimensity 9200 Plus Octa core        MediaTek        8.0
# 3           Snapdragon 7s Gen 2 Octa core      Snapdragon        8.0
# 4           Samsung Exynos 1380 Octa core         Samsung        8.0
# 5            Snapdragon 7 Gen 3 Octa core      Snapdragon        8.0
# 6           Snapdragon 6s Gen 3 Octa core      Snapdragon        8.0
# 7       Snapdragon 7 Plus Gen 3 Octa core      Snapdragon        8.0
# 8            Snapdragon 7 Gen 3 Octa core      Snapdragon        8.0
# 9            Snapdragon 7 Gen 3 Octa core      Snapdragon        8.0
#
#               rear_cameras  num_rear_cameras  main_rear_camera  \
# 0     50+50 MP Rear Camera                 2              50.0
# 1      32+2 MP Rear Camera                 2              32.0
# 2  50+50+50 MP Rear Camera                 3              50.0
# 3     50+13 MP Rear Camera                 2              50.0
# 4    50+8+2 MP Rear Camera                 3              50.0
# 5      50+8 MP Rear Camera                 2              50.0
# 6      50+8 MP Rear Camera                 2              50.0
# 7      50+8 MP Rear Camera                 2              50.0
# 8  50+13+10 MP Rear Camera                 3              50.0
# 9     50+50 MP Rear Camera                 2              50.0
#
#    num_high_resolution_cameras       front_cameras  num_front_cameras  \
# 0                            2  50 MP Front Camera                  1
# 1                            1   8 MP Front Camera                  1
# 2                            3  50 MP Front Camera                  1
# 3                            1  32 MP Front Camera                  1
# 4                            1  13 MP Front Camera                  1
# 5                            1  16 MP Front Camera                  1
# 6                            1  32 MP Front Camera                  1
# 7                            1  16 MP Front Camera                  1
# 8                            1  50 MP Front Camera                  1
# 9                            2  50 MP Front Camera                  1
#
#    main_front_camera                                     display display_size  \
# 0               50.0       6.78″ (17.22 cm) 120Hz AMOLED Display         6.78
# 1                8.0          6.67″ (16.94 cm) 120Hz LCD Display         6.67
# 2               50.0       6.78″ (17.22 cm) 120Hz AMOLED Display         6.78
# 3               32.0       6.67″ (16.94 cm) 144Hz P-OLED Display         6.67
# 4               13.0  6.6″ (16.76 cm) 120Hz Super AMOLED Display          6.6
# 5               16.0        6.7″ (17.02 cm) 120Hz AMOLED Display          6.7
# 6               32.0       6.67″ (16.94 cm) 120Hz P-OLED Display         6.67
# 7               16.0       6.74″ (17.12 cm) 120Hz AMOLED Display         6.74
# 8               50.0        6.7″ (17.02 cm) 144Hz P-OLED Display          6.7
# 9               50.0       6.78″ (17.22 cm) 120Hz AMOLED Display         6.78
#
#   refresh_rate  display_type        ram_internal_memory  ram  storage  \
# 0        120Hz        AMOLED  8 GB RAM | 128 GB Storage  8.0    128.0
# 1        120Hz       IPS LCD  6 GB RAM | 128 GB Storage  6.0    128.0
# 2        120Hz        AMOLED  8 GB RAM | 256 GB Storage  8.0    256.0
# 3        144Hz        P-OLED  8 GB RAM | 128 GB Storage  8.0    128.0
# 4        120Hz  Super AMOLED  6 GB RAM | 128 GB Storage  6.0    128.0
# 5        120Hz        AMOLED  8 GB RAM | 128 GB Storage  8.0    128.0
# 6        120Hz        P-OLED  8 GB RAM | 128 GB Storage  8.0    128.0
# 7        120Hz        AMOLED  8 GB RAM | 128 GB Storage  8.0    128.0
# 8        144Hz        P-OLED  8 GB RAM | 256 GB Storage  8.0    256.0
# 9        120Hz        AMOLED  8 GB RAM | 128 GB Storage  8.0    128.0
#
#                          battery battery_capacity charging operating_system  \
# 0   5500 mAh | 80W Fast Charging             5500       80   Android v14 OS
# 1   5100 mAh | 45W Fast Charging             5100       45   Android v14 OS
# 2   5500 mAh | 80W Fast Charging             5500       80   Android v14 OS
# 3   5000 mAh | 68W Fast Charging             5000       68   Android v14 OS
# 4   6000 mAh | 25W Fast Charging             6000       25   Android v14 OS
# 5  5500 mAh | 100W Fast Charging             5500      100   Android v14 OS
# 6   5000 mAh | 33W Fast Charging             5000       33   Android v14 OS
# 7  5500 mAh | 100W Fast Charging             5500      100   Android v14 OS
# 8  4500 mAh | 125W Fast Charging             4500      125   Android v14 OS
# 9   5000 mAh | 80W Fast Charging             5000       80   Android v14 OS
#
#    os_type os_version            additional_features  has_fingerprint  has_5g  \
# 0  Android        v14        5G | Fingerprint Sensor             True    True
# 1  Android        v14        5G | Fingerprint Sensor             True    True
# 2  Android        v14        5G | Fingerprint Sensor             True    True
# 3  Android        v14  5G | NFC | Fingerprint Sensor             True    True
# 4  Android        v14  5G | NFC | Fingerprint Sensor             True    True
# 5  Android        v14        5G | Fingerprint Sensor             True    True
# 6  Android        v14        5G | Fingerprint Sensor             True    True
# 7  Android        v14  5G | NFC | Fingerprint Sensor             True    True
# 8  Android        v14  5G | NFC | Fingerprint Sensor             True    True
# 9  Android        v14        5G | Fingerprint Sensor             True    True
#
#    has_nfc
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# 9    False

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2248 entries, 0 to 2879
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_name                   2248 non-null   object
#  1   brand                        2248 non-null   object
#  2   price                        2248 non-null   object
#  3   expert_rating                1398 non-null   float64
#  4   user_rating                  2248 non-null   object
#  5   avg_user_rating              2179 non-null   object
#  6   num_ratings                  2179 non-null   float64
#  7   processor                    2248 non-null   object
#  8   processor_brand              2248 non-null   object
#  9   num_cores                    2073 non-null   float64
#  10  rear_cameras                 2248 non-null   object
#  11  num_rear_cameras             2248 non-null   int64
#  12  main_rear_camera             2248 non-null   float64
#  13  num_high_resolution_cameras  2248 non-null   int32
#  14  front_cameras                2248 non-null   object
#  15  num_front_cameras            2248 non-null   int64
#  16  main_front_camera            2248 non-null   float64
#  17  display                      2248 non-null   object
#  18  display_size                 2248 non-null   object
#  19  refresh_rate                 2248 non-null   object
#  20  display_type                 2248 non-null   object
#  21  ram_internal_memory          2248 non-null   object
#  22  ram                          2248 non-null   float64
#  23  storage                      2248 non-null   float64
#  24  battery                      2248 non-null   object
#  25  battery_capacity             2248 non-null   object
#  26  charging                     1321 non-null   object
#  27  operating_system             2248 non-null   object
#  28  os_type                      2248 non-null   object
#  29  os_version                   2248 non-null   object
#  30  additional_features          2248 non-null   object
#  31  has_fingerprint              2248 non-null   bool
#  32  has_5g                       2248 non-null   bool
#  33  has_nfc                      2248 non-null   bool
# dtypes: bool(3), float64(7), int32(1), int64(2), object(21)
# memory usage: 624.3+ KB

# %% [markdown]
# dropping columns which no further required. and saving into csv file for further analysis

# %%
df.columns
# Out:
# Index(['model_name', 'brand', 'price', 'expert_rating', 'user_rating',
#        'avg_user_rating', 'num_ratings', 'processor', 'processor_brand',
#        'num_cores', 'rear_cameras', 'num_rear_cameras', 'main_rear_camera',
#        'num_high_resolution_cameras', 'front_cameras', 'num_front_cameras',
#        'main_front_camera', 'display', 'display_size', 'refresh_rate',
#        'display_type', 'ram_internal_memory', 'ram', 'storage', 'battery',
#        'battery_capacity', 'charging', 'operating_system', 'os_type',
#        'os_version', 'additional_features', 'has_fingerprint', 'has_5g',
#        'has_nfc'],
#       dtype='object')

# %%
df.to_csv('smartphones_cleaned_V1.csv', index=False)

# %%
df.drop(columns=['user_rating', 'rear_cameras', 'front_cameras', 'display', 'ram_internal_memory', 'battery', 'operating_system', 'additional_features'], inplace=True)

# %%
df.to_csv('smartphones_cleaned_V2.csv', index=False)
